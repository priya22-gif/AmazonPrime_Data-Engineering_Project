# %%
files_array = [
    {
     "sourcefolder" : "AmazonPrime_directors",
     "targetfolder" : "AmazonPrime_directors"
    },
    {
     "sourcefolder" : "AmazonPrime_cast",
     "targetfolder" : "AmazonPrime_cast"
    },
    {
     "sourcefolder" : "AmazonPrime_categories",
     "targetfolder" : "AmazonPrime_categories"
    },
    {
     "sourcefolder" : "AmazonPrime_countries",
     "targetfolder" : "AmazonPrime_countries"
    }

]

# %%
dbutils.jobs.taskValues.set("files",files_array)
